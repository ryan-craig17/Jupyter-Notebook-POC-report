# %%
#  2021 Aircraft Final Distribution Study

---

## Counts
Last year we had **** total records with values. Of those values, *** (***%) had no change in value, *** (***%) decreased in value, while *** (***%) increased in value.

In 2021 we had **** Aircraft with recorded values for this year and last year. Of these values, **** (****%) indicated no change from last year's values. 
*** (****%) indicated a decrease in value from last year.
*** (****%) indicated an increase in value from last year.

This change indicates that roughly **% (****% exactly) more of recorded plane values indicated no change in value from last year. 
This also indicates ****% less decreases in value compared to last year as well as an ***% less increases in value compared to last year.

Below are the percentiles of last year's values compared to this year's values.
# Out:
#   File "<ipython-input-2-a587e737377a>", line 3
#     ---
#        ^
# SyntaxError: invalid syntax

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell

s = pd.read_csv("2020 Values.csv")
s["2020 Values"].describe().apply(lambda x: format(x, 'f'))
# Out:
# count        1660.000000
# mean       -26665.481325
# std        333062.716887
# min      -9259000.000000
# 25%             0.000000
# 50%             0.000000
# 75%          1600.000000
# max       1331000.000000
# Name: 2020 Values, dtype: object

# %%
s1 = pd.read_csv("2021 Value Differences.csv")
pd.options.display.float_format = '{:.5f}'.format
s1.describe()
# Out:
#        2021 Value differences
# count              2044.00000
# mean             -24043.88454
# std              223865.11477
# min            -4437000.00000
# 25%                   0.00000
# 50%                   0.00000
# 75%                   0.00000
# max             6597000.00000

# %%
## Interpreting the Results
Here we can see this picture more clearly. We see that in 2020, **% of cases had a value change of no more than $**** while **% of cases indicated no change in value. 
When we look at this year, we see that roughly **% of cases indicate no change in value.

---

## Plotting the Results
Below are frequency distributions for each year and we can see that they are similar, with much less cases increasing in value from last year.
Both plots show the negative skew shown in the results above.

# %%
plt.style.use('ggplot')
plt.hist(s, bins=[-400000, -50000, 0, 50000, 400000])
plt.title('2020 Aircraft Value Changes')
plt.xlabel('Value Difference')
plt.ylabel('Frequency')
plt.ticklabel_format(useOffset=False)
plt.xticks(fontsize=8)

plt.show()

# %%
plt.style.use('ggplot')
plt.hist(s1, bins=[-400000, -50000, 0, 50000, 400000]);
plt.title('2021 Aircraft Value Changes')
plt.xlabel('Value Difference')
plt.ylabel('Frequency')
plt.ylim(0,1200)
plt.xticks(fontsize = 8)
plt.xticks

plt.show()
